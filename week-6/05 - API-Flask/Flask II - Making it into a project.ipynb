# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Structure-of-the-repo" data-toc-modified-id="Structure-of-the-repo-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Structure of the repo</a></span><ul class="toc-item"><li><span><a href="#main.py" data-toc-modified-id="main.py-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>main.py</a></span></li><li><span><a href="#src" data-toc-modified-id="src-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>src</a></span></li><li><span><a href="#Data" data-toc-modified-id="Data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Data</a></span><ul class="toc-item"><li><span><a href="#Through-code:-create-database,-connect-&amp;-load" data-toc-modified-id="Through-code:-create-database,-connect-&amp;-load-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Through code: create database, connect &amp; load</a></span><ul class="toc-item"><li><span><a href="#If-the-database-DOESN'T-exist:" data-toc-modified-id="If-the-database-DOESN'T-exist:-1.3.1.1"><span class="toc-item-num">1.3.1.1&nbsp;&nbsp;</span>If the database DOESN'T exist:</a></span></li><li><span><a href="#If-the-database-exists:" data-toc-modified-id="If-the-database-exists:-1.3.1.2"><span class="toc-item-num">1.3.1.2&nbsp;&nbsp;</span>If the database exists:</a></span></li></ul></li><li><span><a href="#Manually:-load" data-toc-modified-id="Manually:-load-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Manually: load</a></span></li></ul></li><li><span><a href="#config" data-toc-modified-id="config-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>config</a></span></li><li><span><a href="#tools" data-toc-modified-id="tools-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>tools</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Structure of the repo

# %% [markdown]
# - `main.py`
# - `src` folder
# - functions within `src` folder
# - `jupyternotebook`: it will do one get & one post
#
#
# - `README.md`
# - `.gitignore`
# - `.env`
#
#
#
# - `data` or `input` & `output` folders
# - `images` folder

# %% [markdown]
# ## main.py

# %% [markdown]
# `main.py` will contain:
#
# - Imports from the src
# - app declared as `app = Flask(__name__)`
# - `@app.route("paths")` & functions
# - if __name__ == '__main__':
#     app.run(debug=False)
# - `debug`

# %% [markdown]
# ## src

# %% [markdown]
# `src` will contain:

# %% [markdown]
# - a python file for each functionality: they will be imported into `main.py`

# %% [markdown]
# ## Data

# %% [markdown]
# Make sure you load it into your database. Some help:

# %% [markdown]
# ### Through code: create database, connect & load

# %% [markdown]
# #### If the database DOESN'T exist:

# %% [markdown]
# - Go into your MySQL Workbench and run:
# ```sql
# CREATE DATABASE IF NOT EXISTS thenameofyourdatabase;
# ```
# - Refresh your workbench
# - Back to jupyter:

# %% [markdown]
# #### If the database exists:

# %% [markdown]
# ```python
# import sqlalchemy as alch
# import pandas as pd
# import os
#
# # Establishing connection
# password = os.getenv("Make sure your .env is in path & get the name of the variable that holds the password")
# dbName = "the name of your database"
# connectionData = f"mysql+pymysql://root:{password}@localhost/{dbName}"
# engine = alch.create_engine(connectionData)
#
# # Loading to the new info
# table = "name of the table you want to create"
# df = pd.read_csv("path to the file you want to load")
# df.to_sql(table, con=engine)
#
# # Checking it works
# sql_df = pd.read_sql(
#     f"SELECT * FROM {table};",
#     con=engine)
# sql_df.sample()
# ```

# %% [markdown]
# ### Manually: load

# %% [markdown]
# - Create your database
# - After refreshing, right click on the name of your database: Table Data Import Wizard

# %% [markdown]
# ![Screenshot%202022-08-13%20at%2015.14.31.png](attachment:Screenshot%202022-08-13%20at%2015.14.31.png)

# %% [markdown]
# ## config

# %% [markdown]
# - configuration for your databases

# %% [markdown]
# ## tools

# %% [markdown]
# - functions to do queries on your databases
