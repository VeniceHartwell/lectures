# %% [markdown]
# # <center>📦🧹🔍ETL 🔍🧹📦<center>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#What-does-ETL-stand-for?" data-toc-modified-id="What-does-ETL-stand-for?-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>What does ETL stand for?</a></span></li><li><span><a href="#What-are-we-going-to-do?" data-toc-modified-id="What-are-we-going-to-do?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>What are we going to do?</a></span></li><li><span><a href="#We-import-libraries" data-toc-modified-id="We-import-libraries-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>We import libraries</a></span></li><li><span><a href="#Mission-1:-Obtain-the-Spotify-token-to-use-its-API-🗝" data-toc-modified-id="Mission-1:-Obtain-the-Spotify-token-to-use-its-API-🗝-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Mission 1: Obtain the Spotify token to use its API 🗝</a></span></li><li><span><a href="#Spotify-token" data-toc-modified-id="Spotify-token-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Spotify token</a></span></li><li><span><a href="#We-save-the-token-in-our-.env" data-toc-modified-id="We-save-the-token-in-our-.env-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>We save the token in our .env</a></span></li><li><span><a href="#📚-Recap-so-far:" data-toc-modified-id="📚-Recap-so-far:-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>📚 Recap so far:</a></span></li><li><span><a href="#Mission-2:-Get-the-list-of-songs-and-artists-from-the-Spotify-API-🔥" data-toc-modified-id="Mission-2:-Get-the-list-of-songs-and-artists-from-the-Spotify-API-🔥-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Mission 2: Get the list of songs and artists from the Spotify API 🔥</a></span><ul class="toc-item"><li><span><a href="#Spotify-API-call" data-toc-modified-id="Spotify-API-call-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Spotify API call</a></span><ul class="toc-item"><li><span><a href="#We-need-token-and-headers" data-toc-modified-id="We-need-token-and-headers-8.1.1"><span class="toc-item-num">8.1.1&nbsp;&nbsp;</span>We need token and headers</a></span></li><li><span><a href="#Url-+-endpoint" data-toc-modified-id="Url-+-endpoint-8.1.2"><span class="toc-item-num">8.1.2&nbsp;&nbsp;</span>Url + endpoint</a></span></li><li><span><a href="#We-make-the-request" data-toc-modified-id="We-make-the-request-8.1.3"><span class="toc-item-num">8.1.3&nbsp;&nbsp;</span>We make the request</a></span></li><li><span><a href="#Function-to-extract-info-from-dictionaries" data-toc-modified-id="Function-to-extract-info-from-dictionaries-8.1.4"><span class="toc-item-num">8.1.4&nbsp;&nbsp;</span>Function to extract info from dictionaries</a></span></li></ul></li><li><span><a href="#We're-taking-it-to-Pandas!-🐼" data-toc-modified-id="We're-taking-it-to-Pandas!-🐼-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>We're taking it to Pandas! 🐼</a></span></li></ul></li><li><span><a href="#Mission-3:-Get-song-lyrics-with-&quot;lyrics_extractor&quot;" data-toc-modified-id="Mission-3:-Get-song-lyrics-with-&quot;lyrics_extractor&quot;-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Mission 3: Get song lyrics with "lyrics_extractor"</a></span></li><li><span><a href="#We-extract-lyrics-from-the-songs!" data-toc-modified-id="We-extract-lyrics-from-the-songs!-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>We extract lyrics from the songs!</a></span><ul class="toc-item"><li><span><a href="#We-need-to-create-the-KEYs-for-this-library" data-toc-modified-id="We-need-to-create-the-KEYs-for-this-library-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>We need to create the KEYs for this library</a></span></li><li><span><a href="#Since-the-library-needs-the-keys,-we-get-them-out-of-the-.env" data-toc-modified-id="Since-the-library-needs-the-keys,-we-get-them-out-of-the-.env-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Since the library needs the keys, we get them out of the .env</a></span></li><li><span><a href="#store-it-in-a-variable" data-toc-modified-id="store-it-in-a-variable-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>store it in a variable</a></span></li><li><span><a href="#We-are-looking-for-some-lyrics" data-toc-modified-id="We-are-looking-for-some-lyrics-10.4"><span class="toc-item-num">10.4&nbsp;&nbsp;</span>We are looking for some lyrics</a></span></li><li><span><a href="#Many-lyrics!" data-toc-modified-id="Many-lyrics!-10.5"><span class="toc-item-num">10.5&nbsp;&nbsp;</span>Many lyrics!</a></span></li></ul></li></ul></div>

# %% [markdown]
# ![data](https://media.giphy.com/media/xT9C25UNTwfZuk85WP/giphy.gif)

# %% [markdown]
# # Process to follow during the 3 jupyter notebook
# **Jupyter ETL I - Extraction and transformation**
#
# * I get spotify token
# * I make request to the API:
#     - Be careful if the lists have more than 100 songs
#     - Functions that automate the process
# * I get the lyrics of the songs (enrichment) with another library
#
# **Jupyter ETL II - Loading**
#
# * I connect with the databases
# * I create my schema in MySQL
# * I clean the data a bit
# * Check functions before putting my data in the database
# * I load my data to MySQL
# * I export json to load it in MongoDB
#
# **Jupyter NLP**
# * I get the data I want from the databases
# * Tokenize and remove stop words
# * I do Sentiment Analysis with the libraries
# * draw conclusions

# %% [markdown]
# ## What does ETL stand for?
# **Extract**, **Transform** and **Load** is the process that enables organizations to move data from multiple sources, reformat and cleanse it, and load it into another database, data mart, or data warehouse to analyze, or in another operational system to support a business process.

# %% [markdown]
# ## What are we going to do?
# - Learn to use the Spotify API with Oauth
# - Extract data from said API
# - Clean and transform them
# - Enrich them
# - Save them in different databases
# - Make queries to do sentiment analysis with NLP libraries

# %% [markdown]
# ## We import libraries

# %%
import os

import json
import requests
import pyjsonviewer

from functools import reduce
import operator

import pandas as pd
import numpy as np

import lyricsgenius
from lyrics_extractor import SongLyrics

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# https://open.spotify.com/playlist/6DaKU06d03UDpVjPZhF19X?si=4865e6ee629d488b&pt=0ae09e3cb50938ee8f2fc768c208c1c2

# %% [markdown]
# ## Mission 1: Obtain the Spotify token to use its API 🗝

# %% [markdown]
# ## Spotify token
# https://developer.spotify.com/dashboard/login
# We need to have the CLIENT_ID and SECRET_ID tokens, and we store them in the `.env`.
#
#
# 1. Sign up as a devloper
# 2. Create an APP/project on spotify
# 3. Get client_id & client_secret
#
# To call the spotify api and get the token that will allow us to make a request, we are going to have to save a few variables.
# Read the [Documentation](https://developer.spotify.com/documentation/general/guides/authorization-guide/)

# %%
# CLIENT_ID
# CLIENT_SECRET

# token

# %%
# Now that I have my authentication info, I can get the actual token to query for playlists
# I know because of docs

# %%
body_params = {"gran_type":"client_credentials"}

# %%
url = "https://accounts.spotify.com/api/token"

# %%
response = requests.post(url, data=body_params, auth=(CLIENT_ID, CLIENT_SECRET), verify=True)

# %%
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'{"access_token":"BQAKhNHixqdTLH8PT4olupsA77Nh618OGy7S_xuHb7Piq0k2WSsCHii_gY-x5Wtc9hneLtPulFJVRqz2ccXmQruuf0U4o7WBwEPFM1JjNBxnBKX3-cs","token_type":"Bearer","expires_in":3600}'

# %%
type(response.content)
# Out:
# bytes

# %%
token = response.json()["access_token"]
token
# Out:
# 'BQAKhNHixqdTLH8PT4olupsA77Nh618OGy7S_xuHb7Piq0k2WSsCHii_gY-x5Wtc9hneLtPulFJVRqz2ccXmQruuf0U4o7WBwEPFM1JjNBxnBKX3-cs'

# %% [markdown]
# We are going to write all this in a function because, as we have seen, the token expires and so we can call it whenever we want and reuse it. This is what functions are for!

# %%
# I need to hide my credentials: .env

# %%
CLIENT_ID=os.getenv("CLIENT_ID")
CLIENT_SECRET=os.getenv("CLIENT_SECRET")

# %%
def spotifyToken ():
    
    """This function does a requests to Spotify using credentials and retrieves a token"""
    
    # Credentials
    CLIENT_ID=os.getenv("CLIENT_ID")
    CLIENT_SECRET=os.getenv("CLIENT_SECRET")
    
    # Info to do the API call
    body_params = {"grant_type":"client_credentials"}
    url = "https://accounts.spotify.com/api/token"
    
    # Handling request
    response = requests.post(url, data=body_params, auth=(CLIENT_ID, CLIENT_SECRET), verify=True)
    token = response.json()["access_token"]
    
    return token

# %%
token = spotifyToken ()
token
# Out:
# 'BQAg2hf5gTkvZyxUnvHaQfk174uxC4DZQAuHOCTx-Rdq_fyGqzB3K9sDEBFRniFkKvPisAjlMe5vK-0sVFT3oic0ydJh5zWkfs3nnuca9zNxmhnN_g4'

# %% [markdown]
# ## We save the token in our .env

# %%
file = open (".env")
file.write("\n")
file.write(f"token_spotify={token}")
file.close()

# %% [markdown]
# We make a function that does the same thing to be able to reuse it

# %%
def save_token (name, key):
    file = open (".env", "a")
    file.write("\n")
    file.write(f"{name}={key}")
    file.close()

# %%
save_token("hello", "6789067")

# %% [markdown]
# ## 📚 Recap so far:
#
# **What we have done**
# - 1. We get our Spotify authentication
# - 2. With that, we get our spotify `token`: issuing a request.post
# - 3. We save the `token` in the .env <br>
# <br>
#
# **To remember**
#
# - **CLIENT_ID** & **CLIENT_SECRET** is just a means to get the `token`, not the authentication itself.
# - The `token` expires

# %% [markdown]
# ## Mission 2: Get the list of songs and artists from the Spotify API 🔥
# But let's not forget about the [documentation](https://developer.spotify.com/console/)
# The first thing we are going to do is make an API call
# Let's remember the syntax:
#
# `request.get(url, headers)`

# %% [markdown]
# ### Spotify API call

# %% [markdown]
# #### We need token and headers

# %%
token = 'BQAg2hf5gTkvZyxUnvHaQfk174uxC4DZQAuHOCTx-Rdq_fyGqzB3K9sDEBFRniFkKvPisAjlMe5vK-0sVFT3oic0ydJh5zWkfs3nnuca9zNxmhnN_g4'

# %%
headers = {"Authorization":f"Bearer {token}"}

# %% [markdown]
# We take the ID of the list of the share link that comes out in spotify (Link of the song)
# https://open.spotify.com/playlist/6DaKU06d03UDpVjPZhF19X?si=838e81628a2e4a23

# %%
url_base = "https://api.spotify.com/v1/playlists/"

# %% [markdown]
# The ID of the list from which we want to make the request

# %%
playlist_id = playlist_link.split("/")[4].split("?")[0]
playlist_id
# Out:
# '6DaKU06d03UDpVjPZhF19X'

# %%
playlist_link = "https://open.spotify.com/playlist/6DaKU06d03UDpVjPZhF19X?si=eec1225acbea4424"

# %%
#https://open.spotify.com/playlist/       6DaKU06d03UDpVjPZhF19X       si=eec1225acbea4424

# %% [markdown]
# #### Url + endpoint

# %%
query = url_base + playlist_id
query
# Out:
# 'https://api.spotify.com/v1/playlists/6DaKU06d03UDpVjPZhF19X'

# %% [markdown]
# #### We make the request

# %%
response = requests.get(query, headers=headers).json()

# %%
#response
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/6DaKU06d03UDpVjPZhF19X'},
#  'followers': {'href': None, 'total': 7},
#  'href': 'https://api.spotify.com/v1/playlists/6DaKU06d03UDpVjPZhF19X',
#  'id': '6DaKU06d03UDpVjPZhF19X',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d0000b2731630dd349221a35ce03a0ccfab67616d0000b2732e8ed79e177ff6011076f5f0ab67616d0000b27332f29a61d5e3c3bb3c7ae510ab67616d0000b273423ac018d0ec2301e40948a0',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d0000b2731630dd349221a35ce03a0ccfab67616d0000b2732e8ed79e177ff6011076f5f0ab67616d0000b27332f29a61d5e3c3bb3c7ae510ab67616d0000b273423ac018d0ec2301e40948a0',
#    'width': 300},
#   {'height': 60,
#    'url': 'https://mosaic.scdn.co/60/ab67616d0000b2731630dd349221a35ce03a0ccfab67616d0000b2732e8ed79e177ff6011076f5f0ab67616d0000b27332f29a61d5e3c3bb3c7ae510ab67616d0000b273423ac018d0ec2301e40948a0',
#    'width': 60}],
#  'name': 'databcn072022',
#  'owner': {'display_name': 'breogann',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/ferqwertyuiop'},
#   'href': 'https://api.spotify.com/v1/users/ferqwertyuiop',
#   'id': 'ferqwertyuiop',
#   'type': 'user',
#   'uri': 'spotify:user:ferqwertyuiop'},
#  'primary_color': None,
#  'public': False,
#  'snapshot_id': 'OTEsYTMwZDM2ZWUyNTM5MjY3YzA2YTk2MDc4NGE4NGM4ZjFlYjc0MWNkMg==',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/6DaKU06d03UDpVjPZhF19X/tracks?offset=0&limit=100',
#   'items': [{'added_at': '2022-08-10T19:24:48Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ferqwertyuiop'},
#      'href': 'https://api.spotify.com/v1/users/ferqwertyuiop',
#      'id': 'ferqwertyuiop',
#      'type': 'user',
#      'uri': 'spotify:user:ferqwertyuiop'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#         'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#         'id': '716NhGYqD1jl2wI1Qkgq36',
#         'name': 'Bizarrap',
#         'type': 'artist',
#         'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/52iwsT98xCoGgiGntTiR7K'},
#         'href': 'https://api.spotify.com/v1/artists/52iwsT98xCoGgiGntTiR7K',
#         'id': '52iwsT98xCoGgiGntTiR7K',
#         'name': 'Quevedo',
#         'type': 'artist',
#         'uri': 'spotify:artist:52iwsT98xCoGgiGntTiR7K'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4PNqWiJAfjj32hVvlchV5u'},
#       'href': 'https://api.spotify.com/v1/albums/4PNqWiJAfjj32hVvlchV5u',
#       'id': '4PNqWiJAfjj32hVvlchV5u',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2731630dd349221a35ce03a0ccf',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e021630dd349221a35ce03a0ccf',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048511630dd349221a35ce03a0ccf',
#         'width': 64}],
#       'name': 'Quevedo: Bzrp Music Sessions, Vol. 52',
#       'release_date': '2022-07-06',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:4PNqWiJAfjj32hVvlchV5u'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#        'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#        'id': '716NhGYqD1jl2wI1Qkgq36',
#        'name': 'Bizarrap',
#        'type': 'artist',
#        'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/52iwsT98xCoGgiGntTiR7K'},
#        'href': 'https://api.spotify.com/v1/artists/52iwsT98xCoGgiGntTiR7K',
#        'id': '52iwsT98xCoGgiGntTiR7K',
#        'name': 'Quevedo',
#        'type': 'artist',
#        'uri': 'spotify:artist:52iwsT98xCoGgiGntTiR7K'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 198937,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'UYB282201028'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2tTmW7RDtMQtBk7m2rYeSw'},
#      'href': 'https://api.spotify.com/v1/tracks/2tTmW7RDtMQtBk7m2rYeSw',
#      'id': '2tTmW7RDtMQtBk7m2rYeSw',
#      'is_local': False,
#      'name': 'Quevedo: Bzrp Music Sessions, Vol. 52',
#      'popularity': 100,
#      'preview_url': 'https://p.scdn.co/mp3-preview/2bbcf481555f012987ea9f5fd3f771a3f2710922?cid=d5564ef338c84de3be08846509f43e99',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:2tTmW7RDtMQtBk7m2rYeSw'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-08-11T07:25:49Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/chelechepe'},
#      'href': 'https://api.spotify.com/v1/users/chelechepe',
#      'id': 'chelechepe',
#      'type': 'user',
#      'uri': 'spotify:user:chelechepe'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6styCzc1Ej4NxISL0LiigM'},
#         'href': 'https://api.spotify.com/v1/artists/6styCzc1Ej4NxISL0LiigM',
#         'id': '6styCzc1Ej4NxISL0LiigM',
#         'name': 'The Smile',
#         'type': 'artist',
#         'uri': 'spotify:artist:6styCzc1Ej4NxISL0LiigM'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/009EjjwUjtdjvH7UP0wHzi'},
#       'href': 'https://api.spotify.com/v1/albums/009EjjwUjtdjvH7UP0wHzi',
#       'id': '009EjjwUjtdjvH7UP0wHzi',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273423ac018d0ec2301e40948a0',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02423ac018d0ec2301e40948a0',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851423ac018d0ec2301e40948a0',
#         'width': 64}],
#       'name': 'A Light for Attracting Attention',
#       'release_date': '2022-05-13',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:009EjjwUjtdjvH7UP0wHzi'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6styCzc1Ej4NxISL0LiigM'},
#        'href': 'https://api.spotify.com/v1/artists/6styCzc1Ej4NxISL0LiigM',
#        'id': '6styCzc1Ej4NxISL0LiigM',
#        'name': 'The Smile',
#        'type': 'artist',
#        'uri': 'spotify:artist:6styCzc1Ej4NxISL0LiigM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 168172,
#      'episode': False,
#      'explicit': True,
#      'external_ids': {'isrc': 'GBBKS2100393'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2ownDSIYHvydbtauGZW4ln'},
#      'href': 'https://api.spotify.com/v1/tracks/2ownDSIYHvydbtauGZW4ln',
#      'id': '2ownDSIYHvydbtauGZW4ln',
#      'is_local': False,
#      'name': 'You Will Never Work In Television Again',
#      'popularity': 58,
#      'preview_url': 'https://p.scdn.co/mp3-preview/60170a58fed7eb75d862de9b9412fbab497c2428?cid=d5564ef338c84de3be08846509f43e99',
#      'track': True,
#      'track_number': 3,
#      'type': 'track',
#      'uri': 'spotify:track:2ownDSIYHvydbtauGZW4ln'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-08-11T07:35:27Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/disjet'},
#      'href': 'https://api.spotify.com/v1/users/disjet',
#      'id': 'disjet',
#      'type': 'user',
#      'uri': 'spotify:user:disjet'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7FNnA9vBm6EKceENgCGRMb'},
#         'href': 'https://api.spotify.com/v1/artists/7FNnA9vBm6EKceENgCGRMb',
#         'id': '7FNnA9vBm6EKceENgCGRMb',
#         'name': 'Anitta',
#         'type': 'artist',
#         'uri': 'spotify:artist:7FNnA9vBm6EKceENgCGRMb'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/6UsualeqgzPnb8cfaQ5nL7'},
#       'href': 'https://api.spotify.com/v1/albums/6UsualeqgzPnb8cfaQ5nL7',
#       'id': '6UsualeqgzPnb8cfaQ5nL7',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27332f29a61d5e3c3bb3c7ae510',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0232f29a61d5e3c3bb3c7ae510',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485132f29a61d5e3c3bb3c7ae510',
#         'width': 64}],
#       'name': 'Envolver',
#       'release_date': '2021-11-11',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:6UsualeqgzPnb8cfaQ5nL7'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7FNnA9vBm6EKceENgCGRMb'},
#        'href': 'https://api.spotify.com/v1/artists/7FNnA9vBm6EKceENgCGRMb',
#        'id': '7FNnA9vBm6EKceENgCGRMb',
#        'name': 'Anitta',
#        'type': 'artist',
#        'uri': 'spotify:artist:7FNnA9vBm6EKceENgCGRMb'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 193805,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWL12100576'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3IAfUEeaXRX9s9UdKOJrFI'},
#      'href': 'https://api.spotify.com/v1/tracks/3IAfUEeaXRX9s9UdKOJrFI',
#      'id': '3IAfUEeaXRX9s9UdKOJrFI',
#      'is_local': False,
#      'name': 'Envolver',
#      'popularity': 86,
#      'preview_url': 'https://p.scdn.co/mp3-preview/784196314fb6965fbe3a326ff543c8dd6e944ab4?cid=d5564ef338c84de3be08846509f43e99',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:3IAfUEeaXRX9s9UdKOJrFI'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-08-10T19:24:48Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ferqwertyuiop'},
#      'href': 'https://api.spotify.com/v1/users/ferqwertyuiop',
#      'id': 'ferqwertyuiop',
#      'type': 'user',
#      'uri': 'spotify:user:ferqwertyuiop'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6KImCVD70vtIoJWnq6nGn3'},
#         'href': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3',
#         'id': '6KImCVD70vtIoJWnq6nGn3',
#         'name': 'Harry Styles',
#         'type': 'artist',
#         'uri': 'spotify:artist:6KImCVD70vtIoJWnq6nGn3'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5r36AJ6VOJtp00oxSkBZ5h'},
#       'href': 'https://api.spotify.com/v1/albums/5r36AJ6VOJtp00oxSkBZ5h',
#       'id': '5r36AJ6VOJtp00oxSkBZ5h',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2732e8ed79e177ff6011076f5f0',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e022e8ed79e177ff6011076f5f0',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048512e8ed79e177ff6011076f5f0',
#         'width': 64}],
#       'name': "Harry's House",
#       'release_date': '2022-05-20',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:5r36AJ6VOJtp00oxSkBZ5h'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6KImCVD70vtIoJWnq6nGn3'},
#        'href': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3',
#        'id': '6KImCVD70vtIoJWnq6nGn3',
#        'name': 'Harry Styles',
#        'type': 'artist',
#        'uri': 'spotify:artist:6KImCVD70vtIoJWnq6nGn3'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 167303,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USSM12200612'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4Dvkj6JhhA12EX05fT7y2e'},
#      'href': 'https://api.spotify.com/v1/tracks/4Dvkj6JhhA12EX05fT7y2e',
#      'id': '4Dvkj6JhhA12EX05fT7y2e',
#      'is_local': False,
#      'name': 'As It Was',
#      'popularity': 93,
#      'preview_url': 'https://p.scdn.co/mp3-preview/f0c2adc40766cd8c1ec3f2bc6e1cc293a77ba684?cid=d5564ef338c84de3be08846509f43e99',
#      'track': True,
#      'track_number': 4,
#      'type': 'track',
#      'uri': 'spotify:track:4Dvkj6JhhA12EX05fT7y2e'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-08-10T19:24:48Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ferqwertyuiop'},
#      'href': 'https://api.spotify.com/v1/users/ferqwertyuiop',
#      'id': 'ferqwertyuiop',
#      'type': 'user',
#      'uri': 'spotify:user:ferqwertyuiop'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#         'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#         'id': '4q3ewBCX7sLwd24euuV69X',
#         'name': 'Bad Bunny',
#         'type': 'artist',
#         'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/3RQQmkQEvNCY4prGKE6oc5'},
#       'href': 'https://api.spotify.com/v1/albums/3RQQmkQEvNCY4prGKE6oc5',
#       'id': '3RQQmkQEvNCY4prGKE6oc5',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27349d694203245f241a1bcaa72',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0249d694203245f241a1bcaa72',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485149d694203245f241a1bcaa72',
#         'width': 64}],
#       'name': 'Un Verano Sin Ti',
#       'release_date': '2022-05-06',
#       'release_date_precision': 'day',
#       'total_tracks': 23,
#       'type': 'album',
#       'uri': 'spotify:album:3RQQmkQEvNCY4prGKE6oc5'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#        'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#        'id': '4q3ewBCX7sLwd24euuV69X',
#        'name': 'Bad Bunny',
#        'type': 'artist',
#        'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/37230BxxYs9ksS7OkZw3IU'},
#        'href': 'https://api.spotify.com/v1/artists/37230BxxYs9ksS7OkZw3IU',
#        'id': '37230BxxYs9ksS7OkZw3IU',
#        'name': 'Chencho Corleone',
#        'type': 'artist',
#        'uri': 'spotify:artist:37230BxxYs9ksS7OkZw3IU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 178567,
#      'episode': False,
#      'explicit': True,
#      'external_ids': {'isrc': 'QM6MZ2214877'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6Sq7ltF9Qa7SNFBsV5Cogx'},
#      'href': 'https://api.spotify.com/v1/tracks/6Sq7ltF9Qa7SNFBsV5Cogx',
#      'id': '6Sq7ltF9Qa7SNFBsV5Cogx',
#      'is_local': False,
#      'name': 'Me Porto Bonito',
#      'popularity': 99,
#      'preview_url': 'https://p.scdn.co/mp3-preview/8513b15fb5b39966d8eccaa7b8c050c7a570e6e8?cid=d5564ef338c84de3be08846509f43e99',
#      'track': True,
#      'track_number': 3,
#      'type': 'track',
#      'uri': 'spotify:track:6Sq7ltF9Qa7SNFBsV5Cogx'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-08-10T19:24:48Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ferqwertyuiop'},
#      'href': 'https://api.spotify.com/v1/users/ferqwertyuiop',
#      'id': 'ferqwertyuiop',
#      'type': 'user',
#      'uri': 'spotify:user:ferqwertyuiop'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1aSxMhuvixZ8h9dK9jIDwL'},
#         'href': 'https://api.spotify.com/v1/artists/1aSxMhuvixZ8h9dK9jIDwL',
#         'id': '1aSxMhuvixZ8h9dK9jIDwL',
#         'name': 'Kate Bush',
#         'type': 'artist',
#         'uri': 'spotify:artist:1aSxMhuvixZ8h9dK9jIDwL'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5BWl0bB1q0TqyFmkBEupZy'},
#       'href': 'https://api.spotify.com/v1/albums/5BWl0bB1q0TqyFmkBEupZy',
#       'id': '5BWl0bB1q0TqyFmkBEupZy',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27396ab64f52273635308b6bf27',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0296ab64f52273635308b6bf27',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485196ab64f52273635308b6bf27',
#         'width': 64}],
#       'name': 'Hounds Of Love',
#       'release_date': '1985',
#       'release_date_precision': 'year',
#       'total_tracks': 12,
#       'type': 'album',
#       'uri': 'spotify:album:5BWl0bB1q0TqyFmkBEupZy'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1aSxMhuvixZ8h9dK9jIDwL'},
#        'href': 'https://api.spotify.com/v1/artists/1aSxMhuvixZ8h9dK9jIDwL',
#        'id': '1aSxMhuvixZ8h9dK9jIDwL',
#        'name': 'Kate Bush',
#        'type': 'artist',
#        'uri': 'spotify:artist:1aSxMhuvixZ8h9dK9jIDwL'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 298933,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBCNR8500002'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/75FEaRjZTKLhTrFGsfMUXR'},
#      'href': 'https://api.spotify.com/v1/tracks/75FEaRjZTKLhTrFGsfMUXR',
#      'id': '75FEaRjZTKLhTrFGsfMUXR',
#      'is_local': False,
#      'name': 'Running Up That Hill (A Deal With God)',
#      'popularity': 96,
#      'preview_url': 'https://p.scdn.co/mp3-preview/16386d8d6335a6d86f6baae3e49d8cc9135485c2?cid=d5564ef338c84de3be08846509f43e99',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:75FEaRjZTKLhTrFGsfMUXR'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-08-10T19:24:48Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ferqwertyuiop'},
#      'href': 'https://api.spotify.com/v1/users/ferqwertyuiop',
#      'id': 'ferqwertyuiop',
#      'type': 'user',
#      'uri': 'spotify:user:ferqwertyuiop'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#         'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#         'id': '4q3ewBCX7sLwd24euuV69X',
#         'name': 'Bad Bunny',
#         'type': 'artist',
#         'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
# ...
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 216821,
#      'episode': False,
#      'explicit': True,
#      'external_ids': {'isrc': 'GBUM71905642'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3Sj4lCOlYVeHpkvuc9W5Vn'},
#      'href': 'https://api.spotify.com/v1/tracks/3Sj4lCOlYVeHpkvuc9W5Vn',
#      'id': '3Sj4lCOlYVeHpkvuc9W5Vn',
#      'is_local': False,
#      'name': 'Tokyo Drifting',
#      'popularity': 55,
#      'preview_url': None,
#      'track': True,
#      'track_number': 7,
#      'type': 'track',
#      'uri': 'spotify:track:3Sj4lCOlYVeHpkvuc9W5Vn'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-08-11T07:58:21Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/qk6itwwnf6xczuzqyl2l3n5hc'},
#      'href': 'https://api.spotify.com/v1/users/qk6itwwnf6xczuzqyl2l3n5hc',
#      'id': 'qk6itwwnf6xczuzqyl2l3n5hc',
#      'type': 'user',
#      'uri': 'spotify:user:qk6itwwnf6xczuzqyl2l3n5hc'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wFwvxJkurQPU2UdeD4qVt'},
#         'href': 'https://api.spotify.com/v1/artists/6wFwvxJkurQPU2UdeD4qVt',
#         'id': '6wFwvxJkurQPU2UdeD4qVt',
#         'name': 'The Jungle Giants',
#         'type': 'artist',
#         'uri': 'spotify:artist:6wFwvxJkurQPU2UdeD4qVt'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BZ',
#        'CA',
#        'CG',
#        'CH',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'MG',
#        'MH',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'ZA',
#        'ZM'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0RSKnjggldZx2NrKSOD913'},
#       'href': 'https://api.spotify.com/v1/albums/0RSKnjggldZx2NrKSOD913',
#       'id': '0RSKnjggldZx2NrKSOD913',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273c6f12950c0baa55f7133b6ed',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02c6f12950c0baa55f7133b6ed',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851c6f12950c0baa55f7133b6ed',
#         'width': 64}],
#       'name': 'Quiet Ferocity',
#       'release_date': '2017-07-07',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:0RSKnjggldZx2NrKSOD913'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wFwvxJkurQPU2UdeD4qVt'},
#        'href': 'https://api.spotify.com/v1/artists/6wFwvxJkurQPU2UdeD4qVt',
#        'id': '6wFwvxJkurQPU2UdeD4qVt',
#        'name': 'The Jungle Giants',
#        'type': 'artist',
#        'uri': 'spotify:artist:6wFwvxJkurQPU2UdeD4qVt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CG',
#       'CH',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM'],
#      'disc_number': 1,
#      'duration_ms': 222786,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'AU3J01700004'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/290xSzR8Ee9fm82poMg4od'},
#      'href': 'https://api.spotify.com/v1/tracks/290xSzR8Ee9fm82poMg4od',
#      'id': '290xSzR8Ee9fm82poMg4od',
#      'is_local': False,
#      'name': 'Used to Be in Love',
#      'popularity': 61,
#      'preview_url': 'https://p.scdn.co/mp3-preview/5670eac039e196d106e375094b3798ac553b7116?cid=d5564ef338c84de3be08846509f43e99',
#      'track': True,
#      'track_number': 4,
#      'type': 'track',
#      'uri': 'spotify:track:290xSzR8Ee9fm82poMg4od'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2022-08-11T08:01:51Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/qk6itwwnf6xczuzqyl2l3n5hc'},
#      'href': 'https://api.spotify.com/v1/users/qk6itwwnf6xczuzqyl2l3n5hc',
#      'id': 'qk6itwwnf6xczuzqyl2l3n5hc',
#      'type': 'user',
#      'uri': 'spotify:user:qk6itwwnf6xczuzqyl2l3n5hc'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5SXuuuRpukkTvsLuUknva1'},
#         'href': 'https://api.spotify.com/v1/artists/5SXuuuRpukkTvsLuUknva1',
#         'id': '5SXuuuRpukkTvsLuUknva1',
#         'name': 'Baby Keem',
#         'type': 'artist',
#         'uri': 'spotify:artist:5SXuuuRpukkTvsLuUknva1'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/3r46DPIQeBQbjvjjV5mXGg'},
#       'href': 'https://api.spotify.com/v1/albums/3r46DPIQeBQbjvjjV5mXGg',
#       'id': '3r46DPIQeBQbjvjjV5mXGg',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2731bfa23b13d0504fb90c37b39',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e021bfa23b13d0504fb90c37b39',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048511bfa23b13d0504fb90c37b39',
#         'width': 64}],
#       'name': 'The Melodic Blue',
#       'release_date': '2021-09-10',
#       'release_date_precision': 'day',
#       'total_tracks': 16,
#       'type': 'album',
#       'uri': 'spotify:album:3r46DPIQeBQbjvjjV5mXGg'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5SXuuuRpukkTvsLuUknva1'},
#        'href': 'https://api.spotify.com/v1/artists/5SXuuuRpukkTvsLuUknva1',
#        'id': '5SXuuuRpukkTvsLuUknva1',
#        'name': 'Baby Keem',
#        'type': 'artist',
#        'uri': 'spotify:artist:5SXuuuRpukkTvsLuUknva1'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#        'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#        'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#        'name': 'Kendrick Lamar',
#        'type': 'artist',
#        'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 316733,
#      'episode': False,
#      'explicit': True,
#      'external_ids': {'isrc': 'USSM12106861'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0UTyLmkQgPOEIz95OVAJTR'},
#      'href': 'https://api.spotify.com/v1/tracks/0UTyLmkQgPOEIz95OVAJTR',
#      'id': '0UTyLmkQgPOEIz95OVAJTR',
#      'is_local': False,
#      'name': 'range brothers (with Kendrick Lamar)',
#      'popularity': 68,
#      'preview_url': 'https://p.scdn.co/mp3-preview/46fb55cf7dddac33983f45115613ec5c850563e0?cid=d5564ef338c84de3be08846509f43e99',
#      'track': True,
#      'track_number': 4,
#      'type': 'track',
#      'uri': 'spotify:track:0UTyLmkQgPOEIz95OVAJTR'},
#     'video_thumbnail': {'url': None}}],
#   'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 66},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:6DaKU06d03UDpVjPZhF19X'}

# %% [markdown]
# #### Function to extract info from dictionaries

# %%
def getFromDict(diccionario,mapa):
    return reduce(operator.getitem,mapa,diccionario)

# %%
def extract_everything (json):
    comun = {"id_list": ["id"], "list_name": ["name"]}
    mapas = {"name": ["track", "name"], "ironhacker": ["added_by", "id"]}
    total = []
    for elemento in json["tracks"]["items"]:
        track = {key:getFromDict(elemento, value) for key, value in mapas.items()}
        artistas = getFromDict(elemento, ["track", "artists"])
        track["artist"] = [diccionario["name"] for diccionario in artistas]
        track.update({key: getFromDict(json, value) for key,value in comun.items()})
        total.append(track)
    return total

# %%
all_the_songs = extract_everything (response)
all_the_songs[0]

# %%
len(all_the_songs)
# Out:
# 66

# %% [markdown]
# ### We're taking it to Pandas! 🐼
# How? Easy....

# %%
df = pd.DataFrame(all_the_songs)
df
# Out:
#                                        name                 ironhacker  \
# 0     Quevedo: Bzrp Music Sessions, Vol. 52              ferqwertyuiop
# 1   You Will Never Work In Television Again                 chelechepe
# 2                                  Envolver                     disjet
# 3                                 As It Was              ferqwertyuiop
# 4                           Me Porto Bonito              ferqwertyuiop
# ..                                      ...                        ...
# 61                           The Difference  qk6itwwnf6xczuzqyl2l3n5hc
# 62                                       16  qk6itwwnf6xczuzqyl2l3n5hc
# 63                           Tokyo Drifting  qk6itwwnf6xczuzqyl2l3n5hc
# 64                       Used to Be in Love  qk6itwwnf6xczuzqyl2l3n5hc
# 65     range brothers (with Kendrick Lamar)  qk6itwwnf6xczuzqyl2l3n5hc
#
#                            artist                 id_list      list_name
# 0             [Bizarrap, Quevedo]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 1                     [The Smile]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 2                        [Anitta]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 3                  [Harry Styles]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 4   [Bad Bunny, Chencho Corleone]  6DaKU06d03UDpVjPZhF19X  databcn072022
# ..                            ...                     ...            ...
# 61            [Flume, Toro y Moi]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 62                    [Baby Keem]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 63  [Glass Animals, Denzel Curry]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 64            [The Jungle Giants]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 65    [Baby Keem, Kendrick Lamar]  6DaKU06d03UDpVjPZhF19X  databcn072022
#
# [66 rows x 5 columns]

# %%
users_to_replace = {"qk6itwwnf6xczuzqyl2l3n5hc":"Hassan", "31amuhlhlp5dehu4yn2yruxyjhqm":"Ameri"}

# %%
df.sample()
# Out:
#                 name                 ironhacker                  artist  \
# 31  Drankin N Smokin  qk6itwwnf6xczuzqyl2l3n5hc  [Future, Lil Uzi Vert]
#
#                    id_list      list_name
# 31  6DaKU06d03UDpVjPZhF19X  databcn072022

# %%
df["ironhacker"] = df.ironhacker.replace(users_to_replace)

# %%
df
# Out:
#                                        name     ironhacker  \
# 0     Quevedo: Bzrp Music Sessions, Vol. 52  ferqwertyuiop
# 1   You Will Never Work In Television Again     chelechepe
# 2                                  Envolver         disjet
# 3                                 As It Was  ferqwertyuiop
# 4                           Me Porto Bonito  ferqwertyuiop
# ..                                      ...            ...
# 61                           The Difference         Hassan
# 62                                       16         Hassan
# 63                           Tokyo Drifting         Hassan
# 64                       Used to Be in Love         Hassan
# 65     range brothers (with Kendrick Lamar)         Hassan
#
#                            artist                 id_list      list_name
# 0             [Bizarrap, Quevedo]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 1                     [The Smile]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 2                        [Anitta]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 3                  [Harry Styles]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 4   [Bad Bunny, Chencho Corleone]  6DaKU06d03UDpVjPZhF19X  databcn072022
# ..                            ...                     ...            ...
# 61            [Flume, Toro y Moi]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 62                    [Baby Keem]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 63  [Glass Animals, Denzel Curry]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 64            [The Jungle Giants]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 65    [Baby Keem, Kendrick Lamar]  6DaKU06d03UDpVjPZhF19X  databcn072022
#
# [66 rows x 5 columns]

# %% [markdown]
# # 📚 Recap so far:
#
# **What we did**
# - 0. We call the spotify API with a request of the type post so that it gives me the token
# - 1. We made a call to the Spotify API: to get the list information
# - 2. We get only the songs and artists from the json
# - 3. We make functions that automate processes and reuse code
# - 4. We have a dataframe
# <br>
#
# **To remember**
#
# - Add the `.env` to the `.gitignore`.

# %% [markdown]
# ## Mission 3: Get song lyrics with "lyrics_extractor"
# ## We extract lyrics from the songs!
# Lyrics extractor is a library that scribes some pages of song lyrics for us.
# We take a look at the [documentation](https://pypi.org/project/lyrics-extractor/) ALWAYS, especially the **Requirements** part that will explain the things we need to have for it to work .
# ### We need to create the KEYs for this library
# 1.1.1. **[First](https://cse.google.com/cse/create/new)**, create a custom search engine: select a website of letters to scrape. for example: www.genius.com <br>
# 1.1.2. **Second**, `Edit your search engine > select your website > Copy your search engine ID`.
# You now have your **GCS_ENGINE_ID**<br>
# 1.1.3. **[Then](https://developers.google.com/custom-search/v1/overview)**, `Get a key > Select project > copy search engine API key`. You now have your **GCS_API_KEY**.

# %%
#extract_lyrics = SongLyrics(GCS_API_KEY, GCS_ENGINE_ID)

# %%
#sheeran = get_lyrics("Ed Sheeran", "shape of you")
#sheeran

# %% [markdown]
# ### Since the library needs the keys, we get them out of the .env

# %%
#!pip install lyricsgenius
import lyricsgenius

# %% [markdown]
# 1. Install lyrics genius
# 2. Sign up
# 3. Create an [API client](https://genius.com/api-clients)

# %% [markdown]
# ### store it in a variable
# We save the library in a variable by calling SongLyrics and passing it the keys

# %%
# !cat .env
# Out:
# CLIENT_ID="d5564ef338c84de3be08846509f43e99"
# CLIENT_SECRET="837e7c86fc504b6b92ea54ceeedc4948"
# token_spotify=BQBjFAZ5C2qOvZ1jQMkW89PCku67OllJtpjXfLmtw7kru42o8l6pXxi7eBqqorvWBgCrrCXxESABS2voRNiue1UAmf2Zur3k_ptRCyCqnSbX0HFYSjE
# GCS_ENGINE_ID=69d74d7f35104a2e
# GCS_API_KEY=AIzaSyBZwfTU9PHOy_eiCj8egDt05Vm83qWhtI4

# %%
save_env("genius_secret", "fpFKIlpmgdNFKoMQ0ccQBtSzLAmc5wLppAPnraEKd-N4WvIVnZ2foGJIRJNp_3GJ")

# %%
load_dotenv()
# Out:
# True

# %%
genius_secret = os.getenv("genius_secret")
#genius_secret

# %%
genius = lyricsgenius.Genius(genius_secret)

# %% [markdown]
# ### We are looking for some lyrics

# %%
artist = genius.search_artist("Geordie Kiffer", max_songs=1, include_features=True)
artist
# Out:
# Searching for songs by Geordie Kiffer...
#
# Changing artist name to 'Geordie Kieffer'
# Song 1: "The Car Song"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Artist(id, songs, ...)

# %%
song = artist.song("Red Line")
song
# Out:
# Searching for "Red Line" by Geordie Kieffer...
# Done.
# Song(id, artist, ...)

# %%
type(song)
# Out:
# lyricsgenius.types.song.Song

# %%
[element for element in dir(song) if "_" not in element]
# Out:
# ['artist', 'id', 'lyrics', 'path', 'stats', 'title', 'url']

# %%
song.artist
# Out:
# 'Geordie Kieffer'

# %%
song.lyrics
# Out:
# "Red Line Lyrics[Verse 1]\nI come from a long, long line of denim jean\nCut beside all types of fiends\nI robbed the DEA and overdosed\nSpend the cash on guns and coke\nI am the warmonger, more crazy strong\nDroppin' drones inside Iran\nI’m the big, bad, super-charged sex machine\nAll-American, extra lean\n\n[Chorus]\nIf you lose your cool\nBaby, I'll lose mine\nYou draw the red line\nI love crossing red lines\n[Post-Chorus]\nLose your cool\nBaby, I'll lose mine\nYou draw the red line\nI'll see you on the other side\n\n[Verse 2]\nI'll take the M-1-5 and a pound of green\nI'm the triple-round king of ketamine\nI'm not fixin' me, I'm fixin' you\nYou can take these pills, red, white, and blue\nThey go down, down, down with a pack of beer\nThen your eyes go dark and you cannot hear\nI might tie you up, see what you got\nI got a feelin' that you're gonna get hot\n\n[Chorus]\nIf you lose your cool\nBaby, I'll lose mine\nYou draw the red line\nI love crossing red lines\n\n[Bridge]\nFull stop\nYou talk that talk\nYou walk that walk\nWho wears the red line?\nMaybe we can work it out\nMaybe we can work it out\nOh, my friend\nYou seem upset\nWhat's on your mind?\nWoah, you got somethin' you want to say?\nWell, look me in the eye\n[Chorus]\nWoah, if you lose your cool\nMaybe I'll lose mine\nYou draw the red line\nI love crossing red lines2Embed"

# %%
def get_lyrics (artist, song):
    try:
        genius = lyricsgenius.Genius(genius_secret)
        artist = genius.search_artist(artist[0], max_songs=1, include_features=True)
        song = artist.song(song)
        return song.lyrics
    
    except:
        return np.nan

# %%
get_lyrics ("Baby Keem", "16")
# Out:
# Searching for songs by Baby Keem...
#
# Song 1: "Praise God"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "16" by Baby Keem...
# Done.
# "16 Lyrics[Refrain]\nBorn into status, tell nobody that you never had it\nDon't tell nobody that you was abandoned\nI'm the only one that know about your tragedy\nI can't feel sorry when you lost random\nI can't feel sorry, you're a lost ransom\nDrown yourself in expensive fabrics\nI think you picked up a lot of bad habits\nJust appreciate yourself\n\n[Chorus]\nWon't you think about you and I?\nJust grab my hand and look me in the eye\nBut this ain't something you should decide\nThis ain't something that you should decide\nWon't you think about you and I?\nJust grab my hand and look me in the eye\nBut this ain't something you should decide\nThis ain't something that you should decide\n[Refrain]\nBorn into status, tell nobody that you never had it\nDon't tell nobody that you was abandonеd\nI'm the only one that know about your tragedy\nI can't feel sorry 'causе your trust random\nI can't feel sorry, you're a lost ransom\nDrown yourself in expensive fabrics\nI think you picked up a lot of bad habits\nJust appreciate yourself\n\n[Chorus]\nWon't you think about you and I?\nJust grab my hand and look me in the eye\nBut this ain't something you should decide\nThis ain't something that you should decide\nWon't you think about you and I?\nJust grab my hand and look me in the eye\nBut this ain't something you should decide\nThis ain't something that you should decide\n\n[Verse]\nMy mama mad at me, I know I fucked up big\nMy girl mad at me, I know I fucked up big\nWhat's love? I guess I'll never understand\nEvery time I say sorry, I do that shit again\nCheck, check, check, I made a promise\nThat I would never leave you stressed, I would be honest\nI should have never sent that text, I will be honest\nI'm sorry for the things I said, I will be honest\n[Chorus]\nWon't you think about you and I?\nJust grab my hand and look me in the eye\nBut this ain't something you should decide\nThis ain't something that you should decide\nWon't you think about you and I?\nJust grab my hand and look me in the eye\nBut this ain't something you should decide\nThis ain't something that you should decide25Embed"

# %% [markdown]
# ### Many lyrics!

# %%
df
# Out:
#                                        name     ironhacker  \
# 0     Quevedo: Bzrp Music Sessions, Vol. 52  ferqwertyuiop
# 1   You Will Never Work In Television Again     chelechepe
# 2                                  Envolver         disjet
# 3                                 As It Was  ferqwertyuiop
# 4                           Me Porto Bonito  ferqwertyuiop
# ..                                      ...            ...
# 56                  White Lies - EP Version     chelechepe
# 57                                 Red Line     chelechepe
# 58                                Crave You     chelechepe
# 59                     Design of the Future     chelechepe
# 60                    If I Ever Feel Better     chelechepe
#
#                            artist                 id_list      list_name
# 0             [Bizarrap, Quevedo]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 1                     [The Smile]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 2                        [Anitta]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 3                  [Harry Styles]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 4   [Bad Bunny, Chencho Corleone]  6DaKU06d03UDpVjPZhF19X  databcn072022
# ..                            ...                     ...            ...
# 56                    [Max Frost]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 57              [Geordie Kieffer]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 58   [Flight Facilities, Giselle]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 59                [The Architect]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 60                      [Phoenix]  6DaKU06d03UDpVjPZhF19X  databcn072022
#
# [61 rows x 5 columns]

# %%
df_test = df.sample(1)
df_test
# Out:
#                name     ironhacker       artist                 id_list  \
# 6  Tití Me Preguntó  ferqwertyuiop  [Bad Bunny]  6DaKU06d03UDpVjPZhF19X
#
#        list_name
# 6  databcn072022

# %%
df_test["artist"]
# Out:
# 6    [Bad Bunny]
# Name: artist, dtype: object

# %%
test_string = "[Joji]"
test_string[1:-1]
# Out:
# 'Joji'

# %%
type(df_test["artist"])
# Out:
# pandas.core.series.Series

# %%
df_test.iloc[0]["artist"]
# Out:
# ['Bad Bunny']

# %%
df_test["artist"]
# Out:
# 6    [Bad Bunny]
# Name: artist, dtype: object

# %%
df_test
# Out:
#                name     ironhacker       artist                 id_list  \
# 6  Tití Me Preguntó  ferqwertyuiop  [Bad Bunny]  6DaKU06d03UDpVjPZhF19X
#
#        list_name
# 6  databcn072022

# %%
df["newcolumn"] = df.apply(lambda x: ["name"][0].upper())
df
# Out:
#                                        name     ironhacker  \
# 0     Quevedo: Bzrp Music Sessions, Vol. 52  ferqwertyuiop
# 1   You Will Never Work In Television Again     chelechepe
# 2                                  Envolver         disjet
# 3                                 As It Was  ferqwertyuiop
# 4                           Me Porto Bonito  ferqwertyuiop
# ..                                      ...            ...
# 56                  White Lies - EP Version     chelechepe
# 57                                 Red Line     chelechepe
# 58                                Crave You     chelechepe
# 59                     Design of the Future     chelechepe
# 60                    If I Ever Feel Better     chelechepe
#
#                            artist                 id_list      list_name  \
# 0             [Bizarrap, Quevedo]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 1                     [The Smile]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 2                        [Anitta]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 3                  [Harry Styles]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 4   [Bad Bunny, Chencho Corleone]  6DaKU06d03UDpVjPZhF19X  databcn072022
# ..                            ...                     ...            ...
# 56                    [Max Frost]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 57              [Geordie Kieffer]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 58   [Flight Facilities, Giselle]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 59                [The Architect]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 60                      [Phoenix]  6DaKU06d03UDpVjPZhF19X  databcn072022
#
#    newcolumn
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 56       NaN
# 57       NaN
# 58       NaN
# 59       NaN
# 60       NaN
#
# [61 rows x 6 columns]

# %%
df_test["lyrics"] = df_test.apply(lambda x: get_lyrics(x["artist"], x["name"]), axis=1)
df_test
# Out:
# Searching for songs by Bad Bunny...
#
# Song 1: "Te Boté (Remix)"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Searching for "Tití Me Preguntó" by Bad Bunny...
# Done.
#                name     ironhacker       artist                 id_list  \
# 6  Tití Me Preguntó  ferqwertyuiop  [Bad Bunny]  6DaKU06d03UDpVjPZhF19X
#
#        list_name newcolumn                                             lyrics
# 6  databcn072022         T  Tití Me Preguntó Lyrics[Letra de "Tití Me Preg...

# %%
df["lyrics"] = df.apply(lambda x: get_lyrics(x["artist"], x["name"]), axis=1)
df

# %%
df
# Out:
#                                        name     ironhacker  \
# 0     Quevedo: Bzrp Music Sessions, Vol. 52  ferqwertyuiop
# 1   You Will Never Work In Television Again     chelechepe
# 2                                  Envolver         disjet
# 3                                 As It Was  ferqwertyuiop
# 4                           Me Porto Bonito  ferqwertyuiop
# ..                                      ...            ...
# 61                           The Difference         Hassan
# 62                                       16         Hassan
# 63                           Tokyo Drifting         Hassan
# 64                       Used to Be in Love         Hassan
# 65     range brothers (with Kendrick Lamar)         Hassan
#
#                            artist                 id_list      list_name  \
# 0             [Bizarrap, Quevedo]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 1                     [The Smile]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 2                        [Anitta]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 3                  [Harry Styles]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 4   [Bad Bunny, Chencho Corleone]  6DaKU06d03UDpVjPZhF19X  databcn072022
# ..                            ...                     ...            ...
# 61            [Flume, Toro y Moi]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 62                    [Baby Keem]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 63  [Glass Animals, Denzel Curry]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 64            [The Jungle Giants]  6DaKU06d03UDpVjPZhF19X  databcn072022
# 65    [Baby Keem, Kendrick Lamar]  6DaKU06d03UDpVjPZhF19X  databcn072022
#
#                                                lyrics
# 0   July 2022 Singles Release Calendar Lyrics7/1\n...
# 1   You Will Never Work in Television Again Lyrics...
# 2   Envolver Lyrics[Letra de "Envolver"]\n\n[Intro...
# 3   As It Was Lyrics[Intro]\nCome on, Harry, we wa...
# 4   Me Porto Bonito Lyrics[Letra de "Me Porto Boni...
# ..                                                ...
# 61  The Difference Lyrics[Verse 1]\nThe difference...
# 62  16 Lyrics[Refrain]\nBorn into status, tell nob...
# 63  Tokyo Drifting Lyrics[Intro: Denzel Curry]\nDr...
# 64  Used To Be In Love Lyrics[Verse 1]\nYou could ...
# 65  RapCaviar 10/1/21 Lyrics1. Meek Mill - Sharing...
#
# [66 rows x 6 columns]

# %% [markdown]
# # Export

# %%
df.to_csv("lyrics.csv", index=False)

# %% [markdown]
# # RECAP

# %% [markdown]
# - Get lyrics from a given playlist
# - Signed up for the spotify API: cliend_id & client_secret
# - With that: do a POST request to send those credentials and get a token
# - With the token: we're able to get all the songs from a playlist
# - We use the genius library for python to use its API
# - We build a dataframe with all the lyrics from a given spotify playlist
#
# - We saved the code into functions
# - We also createad one to save things into .env
#
# - Reminder: .env & .gitignore
#
# - By putting all the functions together: we can build a script that by passing ONE link (provided you have spotify credentials): result is a pandas daraframe with songs & lryics
#
# Input: one link
# Output: a whole dataframe with info from two sources
